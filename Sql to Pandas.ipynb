# %%
import pandas as pd

# %%
url = (
    "https://raw.github.com/pandas-dev"
    "/pandas/main/pandas/tests/io/data/csv/tips.csv"
)

# %%
df=pd.read_csv(url)

# %%
(df.assign(rnk=df.groupby(["day"])["total_bill"].rank(method="first",ascending=False)).query("rnk>2"))
# Out:
#      total_bill   tip     sex smoker   day    time  size   rnk
# 0         16.99  1.01  Female     No   Sun  Dinner     2  49.0
# 1         10.34  1.66    Male     No   Sun  Dinner     3  68.0
# 2         21.01  3.50    Male     No   Sun  Dinner     3  34.0
# 3         23.68  3.31    Male     No   Sun  Dinner     2  27.0
# 4         24.59  3.61  Female     No   Sun  Dinner     4  23.0
# ..          ...   ...     ...    ...   ...     ...   ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  13.0
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  16.0
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  26.0
# 242       17.82  1.75    Male     No   Sat  Dinner     2  47.0
# 243       18.78  3.00  Female     No  Thur  Dinner     2  20.0
#
# [236 rows x 8 columns]

# %%
(df[df["tip"]>2].assign(rnk=df.sort_values(["sex"])["tip"]).query("rnk>3"))
# Out:
#      total_bill   tip     sex smoker  day    time  size   rnk
# 2         21.01  3.50    Male     No  Sun  Dinner     3  3.50
# 3         23.68  3.31    Male     No  Sun  Dinner     2  3.31
# 4         24.59  3.61  Female     No  Sun  Dinner     4  3.61
# 5         25.29  4.71    Male     No  Sun  Dinner     4  4.71
# 7         26.88  3.12    Male     No  Sun  Dinner     4  3.12
# ..          ...   ...     ...    ...  ...     ...   ...   ...
# 219       30.14  3.09  Female    Yes  Sat  Dinner     4  3.09
# 221       13.42  3.48  Female    Yes  Fri   Lunch     2  3.48
# 232       11.61  3.39    Male     No  Sat  Dinner     2  3.39
# 238       35.83  4.67  Female     No  Sat  Dinner     3  4.67
# 239       29.03  5.92    Male     No  Sat  Dinner     3  5.92
#
# [98 rows x 8 columns]

# %%
(df.assign(rn=df.sort_values(['total_bill'],ascending=False).groupby(['day']).cumcount()+1).query("rn>3").sort_values(["day","rn"]))
# Out:
#      total_bill   tip     sex smoker   day    time  size  rn
# 94        22.75  3.25  Female     No   Fri  Dinner     2   4
# 91        22.49  3.50    Male     No   Fri  Dinner     2   5
# 98        21.01  3.00    Male    Yes   Fri  Dinner     2   6
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2   7
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2   8
# ..          ...   ...     ...    ...   ...     ...   ...  ..
# 126        8.52  1.48    Male     No  Thur   Lunch     2  58
# 135        8.51  1.25  Female     No  Thur   Lunch     2  59
# 145        8.35  1.50  Female     No  Thur   Lunch     2  60
# 195        7.56  1.44    Male     No  Thur   Lunch     2  61
# 149        7.51  2.00    Male     No  Thur   Lunch     2  62
#
# [232 rows x 8 columns]

# %%
(df.assign(rank=df.groupby(["sex"])["tip"].rank(method="min")).query("rank>3"))
# Out:
#      total_bill   tip     sex smoker   day    time  size   rank
# 0         16.99  1.01  Female     No   Sun  Dinner     2    4.0
# 1         10.34  1.66    Male     No   Sun  Dinner     3   20.0
# 2         21.01  3.50    Male     No   Sun  Dinner     3  109.0
# 3         23.68  3.31    Male     No   Sun  Dinner     2  103.0
# 4         24.59  3.61  Female     No   Sun  Dinner     4   70.0
# ..          ...   ...     ...    ...   ...     ...   ...    ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  150.0
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2   18.0
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2   29.0
# 242       17.82  1.75    Male     No   Sat  Dinner     2   23.0
# 243       18.78  3.00  Female     No  Thur  Dinner     2   49.0
#
# [237 rows x 8 columns]

# %%
(df[df["tip"]>2].assign(rank=df.groupby(["day"])["total_bill"].rank(method="first",ascending=False)).query("rank>3").sort_values(by=["rank"],ascending=False))
# Out:
#      total_bill   tip     sex smoker   day    time  size  rank
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2  76.0
# 232       11.61  3.39    Male     No   Sat  Dinner     2  75.0
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2  74.0
# 209       12.76  2.23  Female    Yes   Sat  Dinner     2  71.0
# 51        10.29  2.60  Female     No   Sun  Dinner     2  70.0
# ..          ...   ...     ...    ...   ...     ...   ...   ...
# 91        22.49  3.50    Male     No   Fri  Dinner     2   5.0
# 112       38.07  4.00    Male     No   Sun  Dinner     3   4.0
# 102       44.30  2.50  Female    Yes   Sat  Dinner     3   4.0
# 94        22.75  3.25  Female     No   Fri  Dinner     2   4.0
# 141       34.30  6.70    Male     No  Thur   Lunch     6   4.0
#
# [154 rows x 8 columns]

# %%
(df.assign(rnk=df.groupby(["day"])["total_bill"].rank(method="first",ascending=False)).query("rnk>3").sort_values(["day","rnk"]))
# Out:
#      total_bill   tip     sex smoker   day    time  size   rnk
# 94        22.75  3.25  Female     No   Fri  Dinner     2   4.0
# 91        22.49  3.50    Male     No   Fri  Dinner     2   5.0
# 98        21.01  3.00    Male    Yes   Fri  Dinner     2   6.0
# 93        16.32  4.30  Female    Yes   Fri  Dinner     2   7.0
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2   8.0
# ..          ...   ...     ...    ...   ...     ...   ...   ...
# 126        8.52  1.48    Male     No  Thur   Lunch     2  58.0
# 135        8.51  1.25  Female     No  Thur   Lunch     2  59.0
# 145        8.35  1.50  Female     No  Thur   Lunch     2  60.0
# 195        7.56  1.44    Male     No  Thur   Lunch     2  61.0
# 149        7.51  2.00    Male     No  Thur   Lunch     2  62.0
#
# [232 rows x 8 columns]

# %%
pd.set_option('display.max_rows', 500)
(df[df["tip"]>2].assign(rnk=df.groupby(["sex"])["tip"].rank(method="min")).query("rnk>3"))
# Out:
#      total_bill    tip     sex smoker   day    time  size    rnk
# 2         21.01   3.50    Male     No   Sun  Dinner     3  109.0
# 3         23.68   3.31    Male     No   Sun  Dinner     2  103.0
# 4         24.59   3.61  Female     No   Sun  Dinner     4   70.0
# 5         25.29   4.71    Male     No   Sun  Dinner     4  136.0
# 7         26.88   3.12    Male     No   Sun  Dinner     4   95.0
# 9         14.78   3.23    Male     No   Sun  Dinner     2  101.0
# 11        35.26   5.00  Female     No   Sun  Dinner     4   80.0
# 13        18.43   3.00    Male     No   Sun  Dinner     4   76.0
# 14        14.83   3.02  Female     No   Sun  Dinner     2   56.0
# 15        21.58   3.92    Male     No   Sun  Dinner     2  120.0
# 17        16.29   3.71    Male     No   Sun  Dinner     3  117.0
# 18        16.97   3.50  Female     No   Sun  Dinner     3   65.0
# 19        20.65   3.35    Male     No   Sat  Dinner     3  104.0
# ...

# %%
pd.set_option('display.max_rows',None)
(df[df["tip"]>2].assign(rnk=df.groupby(["sex"])["tip"].rank(method='min')).query("rnk>3"))
# Out:
#      total_bill    tip     sex smoker   day    time  size    rnk
# 2         21.01   3.50    Male     No   Sun  Dinner     3  109.0
# 3         23.68   3.31    Male     No   Sun  Dinner     2  103.0
# 4         24.59   3.61  Female     No   Sun  Dinner     4   70.0
# 5         25.29   4.71    Male     No   Sun  Dinner     4  136.0
# 7         26.88   3.12    Male     No   Sun  Dinner     4   95.0
# 9         14.78   3.23    Male     No   Sun  Dinner     2  101.0
# 11        35.26   5.00  Female     No   Sun  Dinner     4   80.0
# 13        18.43   3.00    Male     No   Sun  Dinner     4   76.0
# 14        14.83   3.02  Female     No   Sun  Dinner     2   56.0
# 15        21.58   3.92    Male     No   Sun  Dinner     2  120.0
# 17        16.29   3.71    Male     No   Sun  Dinner     3  117.0
# 18        16.97   3.50  Female     No   Sun  Dinner     3   65.0
# 19        20.65   3.35    Male     No   Sat  Dinner     3  104.0
# ...

# %%
pd.set_option('display.max_rows',None)
(df.assign(rnk=df.groupby(["day"])["total_bill"].rank(method="first",ascending=False)).query("rnk>3"))
# Out:
#      total_bill   tip     sex smoker   day    time  size   rnk
# 0         16.99  1.01  Female     No   Sun  Dinner     2  49.0
# 1         10.34  1.66    Male     No   Sun  Dinner     3  68.0
# 2         21.01  3.50    Male     No   Sun  Dinner     3  34.0
# 3         23.68  3.31    Male     No   Sun  Dinner     2  27.0
# 4         24.59  3.61  Female     No   Sun  Dinner     4  23.0
# 5         25.29  4.71    Male     No   Sun  Dinner     4  21.0
# 6          8.77  2.00    Male     No   Sun  Dinner     2  75.0
# 7         26.88  3.12    Male     No   Sun  Dinner     4  18.0
# 8         15.04  1.96    Male     No   Sun  Dinner     2  57.0
# 9         14.78  3.23    Male     No   Sun  Dinner     2  59.0
# 10        10.27  1.71    Male     No   Sun  Dinner     2  71.0
# 11        35.26  5.00  Female     No   Sun  Dinner     4   5.0
# 12        15.42  1.57    Male     No   Sun  Dinner     2  56.0
# 13        18.43  3.00    Male     No   Sun  Dinner     4  40.0
# ...
